# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilukka07I/Analise-lunar/blob/analise-foguetes/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Ilukka07I/Analise-lunar.git
# Out:
# Cloning into 'Analise-lunar'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 11.13 KiB | 633.00 KiB/s, done.

# %% [markdown]
# # Atividade 1 (Frequência)

# %%
#Atividade 1 (Frequência): Quantas vezes cada modelo de foguete foi utilizado?

import pandas as pd

df_lua = pd.read_csv('/content/Analise-lunar/Moonlanding.csv')

frequencia = df["Spacecraft"].value_counts()

print("Quantidade de utilizações de cada modelo de foguete:")
print(frequencia)
# Out:
# Quantidade de utilizações de cada modelo de foguete:
# Spacecraft
# Pioneer 0          1
# Luna E-1 No.1      1
# Pioneer 1          1
# Luna E-1 No.2      1
# Pioneer 2          1
#                   ..
# Peregrine          1
# Colmena ? 5        1
# Iris               1
# Nova-C Odysseus    1
# EagleCam           1
# Name: count, Length: 166, dtype: int64

# %%
#Atividade 2 (Média): Em média, quantas vezes um mesmo modelo de foguete foi usado?
import pandas as pd

df = pd.read_csv('/content/Analise-lunar/Moonlanding.csv')
frequencia = df["Spacecraft"].value_counts()

media = frequencia.mean()

print(f"Média de utilizações por modelo: {media:.2f}")
# Out:
# Média de utilizações por modelo: 1.00
